# %%
import tensorflow as tf
mnist = tf.keras.datasets.mnist
(x_train,y_train),(x_test,y_test) = mnist.load_data()
x_train = tf.keras.utils.normalize(x_train)
x_test = tf.keras.utils.normalize(x_test)
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128,activation = tf.nn.relu))
model.add(tf.keras.layers.Dense(128,activation = tf.nn.relu))
model.add(tf.keras.layers.Dense(10,activation = tf.nn.softmax))
model.compile(optimizer = 'adam',loss = 'sparse_categorical_crossentropy',metrics = ['accuracy'])
model.fit(x_train,y_train,epochs = 10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.2505 - accuracy: 0.9269
# Epoch 2/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1029 - accuracy: 0.9680
# Epoch 3/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0729 - accuracy: 0.9765
# Epoch 4/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0532 - accuracy: 0.9821
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0426 - accuracy: 0.9863
# Epoch 6/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0340 - accuracy: 0.9887
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0281 - accuracy: 0.9907
# Epoch 8/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0243 - accuracy: 0.9916
# Epoch 9/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0207 - accuracy: 0.9929
# Epoch 10/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0170 - accuracy: 0.9945

# %%
import matplotlib.pyplot as plt
plt.imshow(x_train[55])
plt.show()

# %%
model.save('model.h5')

# %%
new_model = tf.keras.models.load_model('model.h5')

# %%
prediction = new_model.predict(x_test)

import numpy as np
for i in range(50,60):
    print(np.argmax(prediction[i]))
    plt.imshow(x_test[i])
    plt.show()
# Out:
# 313/313 [==============================] - 1s 3ms/step
# 6
# 3
# 5
# 5
# 6
# 0
# 4
# 1
# 9
# 5

# %%
import tensorflow.compat.v1 as tf
matrix1 = tf.constant([[3, 3]])
matrix2 = tf.constant([[2],
[2]])
product = tf.matmul(matrix1, matrix2) #np.dot(m1, m2)

#method 2
sess = tf.compat.v1.Session('product')

print(sess.run(product))
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[11], line 8
#       5 product = tf.matmul(matrix1, matrix2) #np.dot(m1, m2)
#       7 #method 2
# ----> 8 sess = tf.compat.v1.Session('product')
#      10 print(sess.run(product))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\client\session.py:1604, in Session.__init__(self, target, graph, config)
#    1583 def __init__(self, target='', graph=None, config=None):
#    1584   """Creates a new TensorFlow session.
#    1585
#    1586   If no `graph` argument is specified when constructing the session,
#    (...)
#    1602         protocol buffer with configuration options for the session.
#    1603   """
# -> 1604   super(Session, self).__init__(target, graph, config=config)
#    1605   # NOTE(mrry): Create these on first `__enter__` to avoid a reference cycle.
#    1606   self._default_graph_context_manager = None
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\client\session.py:712, in BaseSession.__init__(self, target, graph, config)
#     709 try:
#     710   # pylint: disable=protected-access
#     711   with self._graph._c_graph.get() as c_graph:
# --> 712     self._session = tf_session.TF_NewSessionRef(c_graph, opts)
#     713   # pylint: enable=protected-access
#     714 finally:
#     715   tf_session.TF_DeleteSessionOptions(opts)
#
# NotFoundError: No session factory registered for the given session options: {target: "product" config: device_count { key: "CPU" value: 1 } device_count { key: "GPU" value: 0 } gpu_options { experimental { } } allow_soft_placement: true experimental { disable_optimize_for_static_graph: true }} Registered factories are {GRPC_SESSION, DIRECT_SESSION}.
